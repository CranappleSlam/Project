# %%
from google.colab import files
import numpy as np
import pandas as pd
uploaded = files.upload()
import io
df2 = pd.read_csv(io.BytesIO(uploaded['C:\\Users\Bert\Documents\Stuffs\Crypto\CoinMetrics\\ada.csv']))
# Dataset is now stored in a Pandas Dataframe
